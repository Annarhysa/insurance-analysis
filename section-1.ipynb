# %% [markdown]
# #### Section 1

# %% [markdown]
# 1) Finding the average patient age for each drug

# %%
import numpy as np
import pandas as pd

# %%
market_basket = pd.read_csv('data/Market-Basket.csv')

# %%
market_basket
# Out:
#     Unnamed: 0     Unnamed: 1   Unnamed: 2 Unnamed: 3
# 0          NaN  Market Basket          NaN        NaN
# 1          NaN            NaN          NaN        NaN
# 2          NaN       variable         code       Drug
# 3          NaN          NDC11     78082761      BEOVU
# 4          NaN          NDC11  50242006001    AVASTIN
# ..         ...            ...          ...        ...
# 59         NaN             PX        J7312    OZURDEX
# 60         NaN             PX        J9035    AVASTIN
# 61         NaN             PX        Q2046      EYLEA
# 62         NaN             PX        Q5124    BYOOVIZ
# 63         NaN             PX        Q5128    CIMERLI
#
# [64 rows x 4 columns]

# %%
market_basket.drop(market_basket.columns[0],axis=1,inplace=True)

# %%
market_basket
# Out:
#        Unnamed: 1   Unnamed: 2 Unnamed: 3
# 0   Market Basket          NaN        NaN
# 1             NaN          NaN        NaN
# 2        variable         code       Drug
# 3           NDC11     78082761      BEOVU
# 4           NDC11  50242006001    AVASTIN
# ..            ...          ...        ...
# 59             PX        J7312    OZURDEX
# 60             PX        J9035    AVASTIN
# 61             PX        Q2046      EYLEA
# 62             PX        Q5124    BYOOVIZ
# 63             PX        Q5128    CIMERLI
#
# [64 rows x 3 columns]

# %%
market_basket.drop([0,1,2],inplace=True)

# %%
market_basket
# Out:
#    Unnamed: 1   Unnamed: 2 Unnamed: 3
# 3       NDC11     78082761      BEOVU
# 4       NDC11  50242006001    AVASTIN
# 5       NDC11  50242006002    AVASTIN
# 6       NDC11  50242006010    AVASTIN
# 7       NDC11  50242006101    AVASTIN
# ..        ...          ...        ...
# 59         PX        J7312    OZURDEX
# 60         PX        J9035    AVASTIN
# 61         PX        Q2046      EYLEA
# 62         PX        Q5124    BYOOVIZ
# 63         PX        Q5128    CIMERLI
#
# [61 rows x 3 columns]

# %%
market_basket.columns = ['variable','code','Drug']

# %%
market_basket
# Out:
#    variable         code     Drug
# 3     NDC11     78082761    BEOVU
# 4     NDC11  50242006001  AVASTIN
# 5     NDC11  50242006002  AVASTIN
# 6     NDC11  50242006010  AVASTIN
# 7     NDC11  50242006101  AVASTIN
# ..      ...          ...      ...
# 59       PX        J7312  OZURDEX
# 60       PX        J9035  AVASTIN
# 61       PX        Q2046    EYLEA
# 62       PX        Q5124  BYOOVIZ
# 63       PX        Q5128  CIMERLI
#
# [61 rows x 3 columns]

# %%
drug_name = market_basket.Drug
drug_name = np.array(drug_name)
drug_name
# Out:
# array(['BEOVU', 'AVASTIN', 'AVASTIN', 'AVASTIN', 'AVASTIN', 'AVASTIN',
#        'SUSVIMO', 'SUSVIMO', 'LUCENTIS', 'LUCENTIS', 'LUCENTIS',
#        'LUCENTIS', 'LUCENTIS', 'LUCENTIS', 'VABYSMO', 'EYLEA', 'EYLEA',
#        'EYLEA_HD', 'EYLEA_HD', 'CIMERLI', 'CIMERLI', 'BYOOVIZ', 'LASER',
#        'LASER', 'LASER', 'LASER', 'LASER', 'MISC', 'MISC', 'LASER',
#        'LASER', 'LASER', 'LASER', 'LASER', 'LASER', 'LASER', 'LASER',
#        'LASER', 'LASER', 'SUSVIMO', 'VABYSMO', 'EYLEA', 'MISC', 'EYLEA',
#        'BEOVU', 'DEXAMETHASONE', 'MACUGEN', 'VABYSMO', 'LUCENTIS',
#        'SUSVIMO', 'STEROIDS', 'STEROIDS', 'VISUDYNE', 'VISUDYNE', 'MISC',
#        'MISC', 'OZURDEX', 'AVASTIN', 'EYLEA', 'BYOOVIZ', 'CIMERLI'],
#       dtype=object)

# %%
drugs = market_basket.code
drugs_arr = np.array(drugs)
drugs_arr
# Out:
# array(['78082761', '50242006001', '50242006002', '50242006010',
#        '50242006101', '50242006110', '50242007812', '50242007855',
#        '50242008001', '50242008002', '50242008003', '50242008201',
#        '50242008202', '50242008203', '50242009601', '61755000501',
#        '61755000502', '61755005001', '61755005101', '70114044001',
#        '70114044101', '71202000901', '66710', '66711', '66761', '66762',
#        '66821', '67027', '67028', '67031', '67039', '67040', '67105',
#        '67108', '67145', '67210', '67220', '67228', '0017T', 'C9093',
#        'C9097', 'C9291', 'C9399', 'J0178', 'J0179', 'J1100', 'J2503',
#        'J2777', 'J2778', 'J2779', 'J3300', 'J3301', 'J3395', 'J3396',
#        'J3490', 'J3590', 'J7312', 'J9035', 'Q2046', 'Q5124', 'Q5128'],
#       dtype=object)

# %%
claims_patients = pd.read_csv('data/Claims-n-Patients.csv')

# %%
claims_patients.shape
# Out:
# (2200, 47)

# %%
claims_patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   claim id                     2200 non-null   int64
#  1   claim date                   2200 non-null   object
#  2   claim line item              2200 non-null   int64
#  3   claim status                 2200 non-null   object
#  4   primary plan payment type    2200 non-null   object
#  5   secondary plan payment type  2200 non-null   object
#  6   tertiary plan payment type   2200 non-null   object
#  7   primary plan name            2200 non-null   object
#  8   secondary plan name          2200 non-null   object
#  9   tertiary plan name           2200 non-null   object
#  10  primary plan type            2200 non-null   object
#  11  secondary plan type          2200 non-null   object
#  12  tertiary plan type           2200 non-null   object
# ...

# %%
type(claims_patients)
# Out:
# pandas.core.frame.DataFrame

# %%
claims_patients.isna().any()
# Out:
# claim id                       False
# claim date                     False
# claim line item                False
# claim status                   False
# primary plan payment type      False
# secondary plan payment type    False
# tertiary plan payment type     False
# primary plan name              False
# secondary plan name            False
# tertiary plan name             False
# primary plan type              False
# secondary plan type            False
# tertiary plan type             False
# reject code                    False
# reject reason                  False
# source claim type              False
# referring provider hcp id      False
# rendering provider hcp id      False
# diagnosis code 1               False
# diagnosis code 2               False
# diagnosis code 3               False
# diagnosis code 4               False
# diagnosis code 5               False
# diagnosis code 6               False
# diagnosis code 7               False
# ...

# %%
array = np.array(claims_patients)

# %%
array
# Out:
# array([[41439, '12/27/2018', 1, ..., 'M', '\xa0', '\xa0'],
#        [98850, '9/2/2021', 1, ..., 'F', '\xa0', '\xa0'],
#        [74412, '3/15/2018', 3, ..., 'F', '\xa0', '\xa0'],
#        ...,
#        [64341, '12/15/2018', 24, ..., 'M', '\xa0', '\xa0'],
#        [64341, '12/14/2018', 14, ..., 'M', '\xa0', '\xa0'],
#        [64341, '12/19/2018', 34, ..., 'M', '\xa0', '\xa0']], dtype=object)

# %%
array.shape
# Out:
# (2200, 47)

# %%
array[0][-1]
# Out:
# '\xa0'

# %%
array2 = []
for row in range(array.shape[0]):
    if array[row][-1] != '\xa0':
        array2.append(array[row])

# %%
clean_claims_patients = pd.DataFrame(array2,columns=claims_patients.columns)

# %%
clean_claims_patients.head()
# Out:
#    claim id claim date  claim line item claim status  \
# 0     28608  4/13/2019                4
# 1     28608  4/13/2019                4
# 2     28608  4/13/2019                4
# 3     28608  4/13/2019                4
# 4     82179  4/25/2019                2
#
#   primary plan payment type secondary plan payment type  \
# 0           Medicare Part D
# 1           Medicare Part D
# 2           Medicare Part D
# 3           Medicare Part D
# 4                  Medicare
#
#   tertiary plan payment type             primary plan name  \
# 0                                 UHC MED ADV GENERAL (NJ)
# 1                                 UHC MED ADV GENERAL (NJ)
# 2                                 UHC MED ADV GENERAL (NJ)
# 3                                 UHC MED ADV GENERAL (NJ)
# 4                             MEDICARE A SOUTH DAKOTA (SD)
#
#   secondary plan name tertiary plan name  ... procedure code treatment code  \
# ...

# %%
clean_claims_patients.shape[0]
# Out:
# 320

# %%
claims_patients_drug = []
for row in range(clean_claims_patients.shape[0]):
    if np.array(clean_claims_patients.iloc[row,-9]) in drugs_arr or np.array(clean_claims_patients.iloc[row,-10]) in drugs_arr:
        claims_patients_drug.append(clean_claims_patients.iloc[row,:])

# %%
claims_patients_drug = pd.DataFrame(claims_patients_drug)
claims_patients_drug
# Out:
#      claim id claim date  claim line item claim status  \
# 88      10194  7/12/2023                2
# 89      10194  7/12/2023                2
# 90      10194  7/12/2023                2
# 91      10194  7/12/2023                2
# 96      24901   4/3/2020                3
# 97      24901   4/3/2020                3
# 98      24901   4/3/2020                3
# 99      24901   4/3/2020                3
# 287     57461  6/30/2022               22
# 288     57461  6/30/2022               22
# 289     57461  6/30/2022               22
# 290     57461  6/30/2022               22
# 316     99569  8/12/2021                6
# 317     99569  8/12/2021                6
# 318     99569  8/12/2021                6
# 319     99569  8/12/2021                6
#
#     primary plan payment type secondary plan payment type  \
# 88                 Commercial
# 89                 Commercial
# 90                 Commercial
# 91                 Commercial
# 96                 Commercial
# ...

# %%
'J2778' in np.array(claims_patients['treatment code'])
# Out:
# True
